# %% [markdown]
# ## Import Package

# %%
import re
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import nltk
nltk.download('averaged_perceptron_tagger')
import nltk
nltk.download('maxent_ne_chunker')
nltk.download('words')
import string
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\h.chater\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\h.chater\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\h.chater\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
def remove_punctuations(text):
    arabic_punctuations = '''`÷×؛<>_()*&^%][ـ،/:"؟.,'{}~¦+|!”…“–ـ'''
    translator = str.maketrans('', '', arabic_punctuations)
    return text.translate(translator)

def usingNltk(sentance,language):
    textToProceed=sentance
    textToProceed=textToProceed.lower()
    
    print("\n############################################## Cleaning text From ponctuation #############################################")
    if language=='english':
        textToProceed=re.sub('[^a-z]',' ',textToProceed)
        print (textToProceed)
    else:
        remove_punctuations(textToProceed)
        print(textToProceed)
    
    print("\n############################################## tokinization #############################################")
    textToProceed=word_tokenize(textToProceed)
    print(textToProceed)
    
    print("\n############################################## cleaning Stop Words #############################################")
    stop_words = stopwords.words(language)
    textToProceed=[word for word in textToProceed if word not in stop_words]
    #print(stop_words)
    print(textToProceed)
    
    print("############################################## Stemming #############################################")
    porter = PorterStemmer()
    textToProceed = [porter.stem(word) for word in textToProceed]
    print(textToProceed)
    
    print("\n############################################## POS Tagging #############################################")
    import nltk
    nltk.download('averaged_perceptron_tagger')
    from nltk import pos_tag
    textToProceed = pos_tag(textToProceed)
    print(textToProceed)
    
    print("\n############################################## Chunking #############################################")
    from nltk import chunk
    textToProceed = chunk.ne_chunk(textToProceed)
    print(textToProceed)
    return textToProceed

# %%
print("############################################## English Text #############################################")
nlptext=usingNltk("""Perhaps one of the most significant advances made by Arabic mathematics began at this time with the work of al-Khwarizmi,
    namely the beginnings of algebra. It is important to understand just how significant this new idea was. It was a revolutionary move away from
    the Greek concept of mathematics which was essentially geometry. Algebra was a unifying theory which allowed rational
    numbers, irrational numbers, geometrical magnitudes, etc., to all be treated as "algebraic objects". It gave mathematics a whole new
    development path so much broader in concept to that which had existed before, and provided a vehicle for future development of the
    subject. Another important aspect of the introduction of algebraic ideas was that it allowed mathematics to be applied to itself in a
    way which had not happened before.""",'english')
print(nlptext)
# Out:
# ############################################## English #############################################
#
# ############################################## Cleaning text From ponctuation #############################################
# ...

# %%
print("############################################## Arabic Text #############################################")
nlptext=usingNltk("ربما كانت أحد أهم التطورات التي قامت بها الرياضيات العربية التي بدأت في هذا الوقت بعمل الخوارزمي و هي بدايات الجبر، و من المهم فهم كيف كانت هذه الفكرة الجديدة مهمة، فقد كانت خطوة ثورية بعيدا عن المفهوم اليوناني للرياضيات التي هي في جوهرها هندسة، الجبر كان نظرية موحدة تتيح الأعداد الكسرية و الأعداد اللا كسرية، و قدم وسيلة للتنمية في هذا الموضوع مستقبلا. و جانب آخر مهم لإدخال أفكار الجبر و هو أنه سمح بتطبيق الرياضيات على نفسها بطريقة لم تحدث من قبل",'arabic')
print(nlptext)
# Out:
# ############################################## Arabic Text #############################################
#
# ############################################## Cleaning text From ponctuation #############################################
# ربما كانت أحد أهم التطورات التي قامت بها الرياضيات العربية التي بدأت في هذا الوقت بعمل الخوارزمي و هي بدايات الجبر، و من المهم فهم كيف كانت هذه الفكرة الجديدة مهمة، فقد كانت خطوة ثورية بعيدا عن المفهوم اليوناني للرياضيات التي هي في جوهرها هندسة، الجبر كان نظرية موحدة تتيح الأعداد الكسرية و الأعداد اللا كسرية، و قدم وسيلة للتنمية في هذا الموضوع مستقبلا. و جانب آخر مهم لإدخال أفكار الجبر و هو أنه سمح بتطبيق الرياضيات على نفسها بطريقة لم تحدث من قبل
#
# ############################################## tokinization #############################################
# ...
